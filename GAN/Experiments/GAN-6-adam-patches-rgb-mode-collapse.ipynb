# %%
import numpy as np
import cv2
import glob
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import Adam
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip drive/MyDrive/data/GAN/patches-normal.zip > /dev/null
# Out:
# replace patches-normal/MyRecord2022-03-23T1224371360_1.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
path = glob.glob("./patches-normal/*.jpg")

# images =[]
# for file in tqdm(path):
#     img = plt.imread(file)
#     # img = cv2.resize(img, (64,64))
#     # plt.imshow(img)
#     img = img / 255. * 2. - 1.
#     images.append(img)
# X_train = np.asarray(images)

np.random.seed(42)
tf.random.set_seed(42)
batch_size = 32
codings_size = 100

def get_image():
   for file in path:
     img = plt.imread(file)
     img = img / 255. * 2. - 1.
     yield img # Your supposed to yield in a loop

dataset = tf.data.Dataset.from_generator(get_image, output_types=(tf.float32))
dataset = dataset.shuffle(1000)
dataset = dataset.batch(batch_size, drop_remainder=True).prefetch(1)

# %%
plt.imshow(np.squeeze((X_train[0] + 1.) / 2.))

# %%
def plot_multiple_images(images, n_cols=None):
    n_cols = n_cols or len(images)
    n_rows = (len(images) - 1) // n_cols + 1
    if images.shape[-1] == 1:
        images = np.squeeze(images, axis=-1)
    plt.figure(figsize=(n_cols, n_rows))
    for index, image in enumerate(images):
        image = (image + 1.) / 2.
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(image)
        plt.axis("off")

# %%
def train_gan(gan, dataset, batch_size, codings_size, n_epochs=1000):
    generator, discriminator = gan.layers
    for i, epoch in enumerate(range(n_epochs)):
        print("Epoch {}/{}".format(epoch + 1, n_epochs))
        for j,  X_batch in enumerate(tqdm(dataset)):
            X_batch = tf.cast(X_batch, tf.float32)
            # phase 1 - training the discriminator
            noise = tf.random.normal(shape=[batch_size, codings_size])
            generated_images = generator(noise)
            X_fake_and_real = tf.concat([generated_images, X_batch], axis=0)
            y1 = tf.constant([[0.]] * batch_size + [[1.]] * batch_size)
            discriminator.trainable = True
            discriminator.train_on_batch(X_fake_and_real, y1)
            # phase 2 - training the generator
            noise = tf.random.normal(shape=[batch_size, codings_size])
            y2 = tf.constant([[1.]] * batch_size)
            discriminator.trainable = False
            gan.train_on_batch(noise, y2)
        if i % 20 == 0:
          gan.save("./drive/MyDrive/models/GAN/6_gan_{}.hdf5".format(i))
          plot_multiple_images(generated_images, 8)
          plt.show()

# %%
# np.random.seed(42)
# tf.random.set_seed(42)
# batch_size = 32
# codings_size = 100
# dataset = tf.data.Dataset.from_tensor_slices(X_train)
# dataset = dataset.shuffle(1000)
# dataset = dataset.batch(batch_size, drop_remainder=True).prefetch(1)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-14-6ff0c557dca9> in <module>()
#       3 batch_size = 32
#       4 codings_size = 100
# ----> 5 dataset = tf.data.Dataset.from_tensor_slices(X_train)
#       6 dataset = dataset.shuffle(1000)
#       7 dataset = dataset.batch(batch_size, drop_remainder=True).prefetch(1)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in from_tensor_slices(tensors, name)
#     791       Dataset: A `Dataset`.
#     792     """
# --> 793     return TensorSliceDataset(tensors, name=name)
#     794
#     795   class _GeneratorState(object):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, element, is_files, name)
#    4475   def __init__(self, element, is_files=False, name=None):
#    4476     """See `Dataset.from_tensor_slices()` for details."""
# -> 4477     element = structure.normalize_element(element)
#    4478     batched_spec = structure.type_spec_from_value(element)
#    4479     self._tensors = structure.to_batched_tensor_list(batched_spec, element)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/util/structure.py in normalize_element(element, element_signature)
#     123           dtype = getattr(spec, "dtype", None)
#     124           normalized_components.append(
# --> 125               ops.convert_to_tensor(t, name="component_%d" % i, dtype=dtype))
#     126   return nest.pack_sequence_as(pack_as, normalized_components)
#     127
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     181         with Trace(trace_name, **trace_kwargs):
#     182           return func(*args, **kwargs)
# --> 183       return func(*args, **kwargs)
#     184
#     185     return wrapped
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1693
#    1694     if ret is None:
# -> 1695       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1696
#    1697     if ret is NotImplemented:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      46 def _default_conversion_function(value, dtype, name, as_ref):
#      47   del as_ref  # Unused.
# ---> 48   return constant_op.constant(value, dtype, name=name)
#      49
#      50
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     266   """
#     267   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 268                         allow_broadcast=True)
#     269
#     270
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     277       with trace.Trace("tf.constant"):
#     278         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 279     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     280
#     281   g = ops.get_default_graph()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     302 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     303   """Creates a constant on the current device."""
# --> 304   t = convert_to_eager_tensor(value, ctx, dtype)
#     305   if shape is None:
#     306     return t
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     100       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101   ctx.ensure_initialized()
# --> 102   return ops.EagerTensor(value, ctx.device_name, dtype)
#     103
#     104
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.

# %%
generator = keras.models.Sequential([
    keras.layers.Dense(5 * 5 * 256, input_shape=[codings_size]),
    keras.layers.Reshape([5, 5, 256]),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2DTranspose(128, kernel_size=5, strides=2, padding="same", activation="selu"),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2DTranspose(64, kernel_size=5, strides=2, padding="same", activation="selu"),
    keras.layers.BatchNormalization(),    
    keras.layers.Conv2DTranspose(32, kernel_size=5, strides=2, padding="same", activation="selu"),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2DTranspose(3, kernel_size=5, strides=2, padding="same", activation="tanh")
])
discriminator = keras.models.Sequential([
    keras.layers.Conv2D(32, kernel_size=5, strides=2, padding="same", activation=keras.layers.LeakyReLU(0.2), input_shape=[80, 80, 3]),
    keras.layers.Dropout(0.4),
    keras.layers.Conv2D(64, kernel_size=5, strides=2, padding="same", activation=keras.layers.LeakyReLU(0.2)), 
    keras.layers.Dropout(0.4),
    keras.layers.Conv2D(128, kernel_size=5, strides=2, padding="same", activation=keras.layers.LeakyReLU(0.2)),
    keras.layers.Dropout(0.4),
    keras.layers.Conv2D(256, kernel_size=5, strides=2, padding="same", activation=keras.layers.LeakyReLU(0.2)),
    keras.layers.Flatten(),
    keras.layers.Dense(1, activation="sigmoid")
])
gan = keras.models.Sequential([generator, discriminator])

# %%
generator.summary()
discriminator.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6400)              646400
#
#  reshape (Reshape)           (None, 5, 5, 256)         0
#
#  batch_normalization (BatchN  (None, 5, 5, 256)        1024
#  ormalization)
#
#  conv2d_transpose (Conv2DTra  (None, 10, 10, 128)      819328
#  nspose)
#
#  batch_normalization_1 (Batc  (None, 10, 10, 128)      512
#  hNormalization)
#
#  conv2d_transpose_1 (Conv2DT  (None, 20, 20, 64)       204864
#  ranspose)
#
#  batch_normalization_2 (Batc  (None, 20, 20, 64)       256
#  hNormalization)
#
#  conv2d_transpose_2 (Conv2DT  (None, 40, 40, 32)       51232
#  ranspose)
#
#  batch_normalization_3 (Batc  (None, 40, 40, 32)       128
#  hNormalization)
#
#  conv2d_transpose_3 (Conv2DT  (None, 80, 80, 3)        2403
#  ranspose)
#
# =================================================================
# Total params: 1,726,147
# Trainable params: 1,725,187
# Non-trainable params: 960
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 40, 40, 32)        2432
#
#  dropout (Dropout)           (None, 40, 40, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 20, 20, 64)        51264
#
#  dropout_1 (Dropout)         (None, 20, 20, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 10, 10, 128)       204928
#
#  dropout_2 (Dropout)         (None, 10, 10, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 5, 5, 256)         819456
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dense_1 (Dense)             (None, 1)                 6401
#
# =================================================================
# Total params: 1,084,481
# Trainable params: 0
# Non-trainable params: 1,084,481
# _________________________________________________________________

# %%
discriminator.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0002), metrics=['mae'])
discriminator.trainable = False
gan.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0002), metrics=['mae'])

# %%
train_gan(gan, dataset, batch_size, codings_size)
# Out:
# Epoch 1/1000
# 2053it [02:20, 14.62it/s]
#   0%|          | 1/65718 [04:45<5203:27:43, 285.05s/it]
# Epoch 2/1000
# 2053it [02:19, 14.70it/s]
# Epoch 3/1000
# 2053it [02:19, 14.77it/s]
# Epoch 4/1000
# 2053it [02:19, 14.77it/s]
# Epoch 5/1000
# 2053it [02:17, 14.88it/s]
# Epoch 6/1000
# 2053it [02:18, 14.84it/s]
# Epoch 7/1000
# 2053it [02:18, 14.81it/s]
# Epoch 8/1000
# 2053it [02:18, 14.81it/s]
# Epoch 9/1000
# 2053it [02:18, 14.78it/s]
# Epoch 10/1000
# 2053it [02:17, 14.93it/s]
# Epoch 11/1000
# 2053it [02:17, 14.88it/s]
# Epoch 12/1000
# 2053it [02:17, 14.92it/s]
# Epoch 13/1000
# 2053it [02:18, 14.82it/s]
# Epoch 14/1000
# 2053it [02:17, 14.91it/s]
# Epoch 15/1000
# 2053it [02:17, 14.90it/s]
# Epoch 16/1000
# 2053it [02:18, 14.81it/s]
# Epoch 17/1000
# 2053it [02:18, 14.87it/s]
# Epoch 18/1000
# 2053it [02:18, 14.87it/s]
# Epoch 19/1000
# 2053it [02:17, 14.92it/s]
# Epoch 20/1000
# 2053it [02:20, 14.62it/s]
# Epoch 21/1000
# 2053it [02:21, 14.48it/s]
# Epoch 22/1000
# 2053it [02:22, 14.41it/s]
# Epoch 23/1000
# 2053it [02:20, 14.57it/s]
# Epoch 24/1000
# 2053it [02:21, 14.56it/s]
# Epoch 25/1000
# 2053it [02:21, 14.51it/s]
# Epoch 26/1000
# 2053it [02:21, 14.55it/s]
# Epoch 27/1000
# 2053it [02:21, 14.52it/s]
# Epoch 28/1000
# 2053it [02:21, 14.56it/s]
# Epoch 335/1000
# 2053it [02:22, 14.42it/s]
# Epoch 336/1000
# 2053it [02:21, 14.50it/s]
# Epoch 337/1000
# 2053it [02:21, 14.46it/s]
# Epoch 338/1000
# 2053it [02:20, 14.61it/s]
# Epoch 339/1000
# 2053it [02:20, 14.65it/s]
# Epoch 340/1000
# 2053it [02:20, 14.63it/s]
# Epoch 341/1000
# 2053it [02:19, 14.69it/s]
# Epoch 342/1000
# 2053it [02:20, 14.59it/s]
# Epoch 343/1000
# 2053it [02:20, 14.60it/s]
# Epoch 344/1000
# 2053it [02:21, 14.51it/s]
# Epoch 345/1000
# 2053it [02:20, 14.58it/s]
# Epoch 346/1000
# 2053it [02:21, 14.53it/s]
# Epoch 347/1000
# 2053it [02:20, 14.61it/s]
# Epoch 348/1000
# 2053it [02:20, 14.65it/s]
# Epoch 349/1000
# 2053it [02:20, 14.61it/s]
# Epoch 350/1000
# 2053it [02:19, 14.71it/s]
# Epoch 351/1000
# 2053it [02:20, 14.64it/s]
# Epoch 352/1000
# 2053it [02:19, 14.68it/s]
# Epoch 353/1000
# 2053it [02:20, 14.65it/s]
# Epoch 354/1000
# 2053it [02:18, 14.77it/s]
# Epoch 355/1000
# 2053it [02:20, 14.66it/s]
# Epoch 356/1000
# 2053it [02:19, 14.69it/s]
# Epoch 357/1000
# 2053it [02:19, 14.69it/s]
# Epoch 358/1000
# 2053it [02:19, 14.71it/s]
# Epoch 359/1000
# 2053it [02:19, 14.73it/s]
# Epoch 360/1000
# 2053it [02:21, 14.48it/s]
# Epoch 361/1000
# 23it [00:02,  8.00it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-dce3399abadd> in <module>()
# ----> 1 train_gan(gan, dataset, batch_size, codings_size)
#
# <ipython-input-13-0817750f557a> in train_gan(gan, dataset, batch_size, codings_size, n_epochs)
#      16             y2 = tf.constant([[1.]] * batch_size)
#      17             discriminator.trainable = False
# ---> 18             gan.train_on_batch(noise, y2)
#      19         if i % 20 == 0:
#      20           gan.save("./drive/MyDrive/models/GAN/6_gan_{}.hdf5".format(i))
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics, return_dict)
#    2089       iterator = data_adapter.single_batch_iterator(self.distribute_strategy, x,
#    2090                                                     y, sample_weight,
# -> 2091                                                     class_weight)
#    2092       self.train_function = self.make_train_function()
#    2093       logs = self.train_function(iterator)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in single_batch_iterator(strategy, x, y, sample_weight, class_weight)
#    1639     dataset = dataset.map(_make_class_weight_map_fn(class_weight))
#    1640   dataset = strategy.experimental_distribute_dataset(dataset)
# -> 1641   return iter(dataset)
#    1642
#    1643
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     484     if context.executing_eagerly() or ops.inside_function():
#     485       with ops.colocate_with(self._variant_tensor):
# --> 486         return iterator_ops.OwnedIterator(self)
#     487     else:
#     488       raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec)
#     753             "When `dataset` is provided, `element_spec` and `components` must "
#     754             "not be specified.")
# --> 755       self._create_iterator(dataset)
#     756
#     757     self._get_next_call_count = 0
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     785                 output_types=self._flat_output_types,
#     786                 output_shapes=self._flat_output_shapes))
# --> 787         gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     788         # Delete the resource when this object is deleted
#     789         self._resource_deleter = IteratorResourceDeleter(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    3314     try:
#    3315       _result = pywrap_tfe.TFE_Py_FastPathExecute(
# -> 3316         _ctx, "MakeIterator", name, dataset, iterator)
#    3317       return _result
#    3318     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
